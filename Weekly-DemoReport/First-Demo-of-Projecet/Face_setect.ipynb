# %% [markdown]
# !pip install roboflow
#
# from roboflow import Roboflow
# rf = Roboflow(api_key="Y6dNPg0e8g6slUzzc9il")
# project = rf.workspace("mohamed-traore-2ekkp").project("face-detection-mik1i")
# version = project.version(24)
# dataset = version.download("yolov5")

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Y6dNPg0e8g6slUzzc9il")
project = rf.workspace("mohamed-traore-2ekkp").project("face-detection-mik1i")
version = project.version(24)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Face-Detection-24 in yolov5pytorch:: 100%|██████████| 7643/7643 [00:00<00:00, 8144.37it/s]

# %%
# !git clone https://github.com/wonbeomjang/yolov5-knowledge-distillation.git
# Out:
# Cloning into 'yolov5-knowledge-distillation'...
# remote: Enumerating objects: 15823, done.
# remote: Total 15823 (delta 0), reused 0 (delta 0), pack-reused 15823 (from 1)
# Receiving objects: 100% (15823/15823), 15.17 MiB | 15.86 MiB/s, done.
# Resolving deltas: 100% (10624/10624), done.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Y6dNPg0e8g6slUzzc9il")
project = rf.workspace("eduardo-ramos-soriano").project("mug-detection")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Mug-Detection-1 in yolov5pytorch:: 100%|██████████| 392/392 [00:00<00:00, 9203.90it/s]

# %%
# !python train.py --data mug.yaml --cfg models/yolov5s_student.yaml --weights '' --batch-size 8 --teacher_weight yolov5s.pt --epochs 40
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 50.1 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-11-09 19:11:28.256181: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-09 19:11:28.274968: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %% [markdown]
# ## Gun Detection project

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Y6dNPg0e8g6slUzzc9il")
project = rf.workspace("dignitas-technologies").project("guns-dvu9k")
version = project.version(5)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to guns-5 in yolov5pytorch:: 100%|██████████| 1274/1274 [00:00<00:00, 7422.44it/s]

# %%
# !python train.py --data gun.yaml --cfg models/yolov5s_student.yaml --weights '' --batch-size 8 --teacher_weight yolov5s.pt --epochs 40
# Out:
# Traceback (most recent call last):
#   File "/content/yolov5-knowledge-distillation/train.py", line 48, in <module>
#     import val as validate  # for end-of-epoch mAP
#   File "/content/yolov5-knowledge-distillation/val.py", line 39, in <module>
#     from models.common import DetectMultiBackend
# ModuleNotFoundError: No module named 'models'

# %%
# %cd yolov5-knowledge-distillation
# Out:
# [Errno 2] No such file or directory: 'yolov5-knowledge-distillation'
# /content/yolov5-knowledge-distillation

# %%
# %cd ..
# Out:
# /content

# %%
# %cd yolov5-knowledge-distillation
# Out:
# /content/yolov5-knowledge-distillation

# %%
# !python train.py --data gun.yaml --cfg models/yolov5s_student.yaml --weights '' --batch-size 8 --teacher_weight yolov5s.pt --epochs 40
# Out:
# Streaming output truncated to the last 5000 lines.
#        7/39      1.41G    0.07904    0.02129          0         20        640:  83% 62/75 [00:16<00:02,  4.94it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/39      1.41G     0.0791    0.02137          0         19        640:  84% 63/75 [00:16<00:02,  4.97it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Y6dNPg0e8g6slUzzc9il")
project = rf.workspace("ntnst").project("lemon-disease-detection-2")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Lemon-Disease-Detection-2-3 in yolov5pytorch:: 100%|██████████| 4260/4260 [00:01<00:00, 3554.55it/s]

# %%
# %cd yolov5-knowledge-distillation
# Out:
# /content/yolov5-knowledge-distillation

# %%
# !python train.py --data lemon.yaml --cfg yolov5s_student.yaml --weights '' --batch-size 8 --teacher_weight yolov5s.pt --epochs 40
# Out:
# Streaming output truncated to the last 5000 lines.
#       29/39      1.54G     0.0425    0.04367  0.0002384         77        640:  41% 96/233 [00:40<00:45,  3.00it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/39      1.54G    0.04243    0.04362  0.0002372         82        640:  42% 97/233 [00:40<00:48,  2.81it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python train.py --data VOC.yaml --cfg models/yolov5s_student.yaml --weights '' --batch-size 8 --teacher_weight yolov5s.pt --epochs 40
