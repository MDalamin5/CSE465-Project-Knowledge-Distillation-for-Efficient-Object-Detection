# %%
# !git clone https://github.com/wonbeomjang/yolov5-knowledge-distillation.git
# Out:
# Cloning into 'yolov5-knowledge-distillation'...
# remote: Enumerating objects: 15823, done.
# remote: Total 15823 (delta 0), reused 0 (delta 0), pack-reused 15823 (from 1)
# Receiving objects: 100% (15823/15823), 15.21 MiB | 12.32 MiB/s, done.
# Resolving deltas: 100% (10617/10617), done.

# %%
# %cd yolov5-knowledge-distillation/
# Out:
# /content/yolov5-knowledge-distillation

# %%
# !python train.py --data VOC.yaml --cfg yolov5s_student.yaml --weights '' --batch-size 8 --teacher_weight yolov5s.pt --epochs 40
# Out:
# Streaming output truncated to the last 5000 lines.
#       16/39      1.93G    0.05021     0.0405    0.03536         31        640:  82% 1697/2069 [09:03<01:31,  4.06it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       16/39      1.93G     0.0502     0.0405    0.03536         34        640:  82% 1698/2069 [09:03<01:37,  3.80it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
