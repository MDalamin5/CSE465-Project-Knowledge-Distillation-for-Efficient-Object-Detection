# %%
# !git clone https://github.com/wonbeomjang/yolov5-knowledge-distillation.git
# Out:
# Cloning into 'yolov5-knowledge-distillation'...
# remote: Enumerating objects: 15823, done.
# remote: Total 15823 (delta 0), reused 0 (delta 0), pack-reused 15823 (from 1)
# Receiving objects: 100% (15823/15823), 15.21 MiB | 16.41 MiB/s, done.
# Resolving deltas: 100% (10617/10617), done.

# %%
# %cd yolov5-knowledge-distillation/
# Out:
# /content/yolov5-knowledge-distillation

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 51.3 MB/s eta 0:00:00
# ...

# %%
# !python train.py --data coco128.yaml --cfg yolov5s.yaml --weights '' --batch-size 64
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-11-09 11:11:06.611703: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-09 11:11:06.633891: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %% [markdown]
# ## Distill knowledge of teacher model

# %%
# !python train.py --data coco128.yaml --cfg yolov5s.yaml --weights '' --batch-size 16 --teacher_weight yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-11-09 12:00:10.370810: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-09 12:00:10.402546: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-09 12:00:10.412379: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# ...

# %%
# !python train.py --data VOC.yaml --cfg yolov5s_student.yaml --weights '' --batch-size 16 --teacher_weight yolov5s.pt --epochs 50
# Out:
# Streaming output truncated to the last 5000 lines.
#        4/49      3.69G    0.06085    0.04408    0.05276         70        640:  31% 316/1035 [03:16<06:54,  1.73it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/49      3.69G    0.06086    0.04408    0.05277         84        640:  31% 317/1035 [03:18<10:13,  1.17it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
