# %%
# !python train.py --data coco128.yaml --cfg yolov5s_student.yaml --weights '' --batch-size 16 --teacher_weight yolov5s.pt
# Out:
# Error decoding JSON from C:\Users\Lenovo\AppData\Roaming\Ultralytics\settings.json. Starting with an empty dictionary.
# train: weights='', teacher_weight=yolov5s.pt, cfg=yolov5s_student.yaml, data=coco128.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# From https://github.com/ultralytics/yolov5
#  * [new branch]        add/weights_dir   -> ultralytics/add/weights_dir
#  * [new branch]        exp/scaleFill     -> ultralytics/exp/scaleFill
# ...

# %%
# !python train.py --data VOC.yaml --cfg models/yolov5s_student.yaml --weights '' --batch-size 8 --teacher_weight yolov5s.pt --epochs 40
# Out:
# train: weights='', teacher_weight=yolov5s.pt, cfg=models/yolov5s_student.yaml, data=VOC.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=40, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 143 commits. Use 'git pull ultralytics master' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5  v7.0-276-g3ea9de36 Python-3.12.4 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
#
# ...

# %%
# !python train.py --data coco128.yaml --cfg yolov5s_student.yaml --weights '' --batch-size 8 --teacher_weight yolov5s.pt --epochs 1
# Out:
# train: weights='', teacher_weight=yolov5s.pt, cfg=yolov5s_student.yaml, data=coco128.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=1, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# From https://github.com/ultralytics/yolov5
#  * [new branch]        dependabot/github_actions/dot-github/workflows/slackapi/slack-github-action-2.0.0 -> ultralytics/dependabot/github_actions/dot-github/workflows/slackapi/slack-github-action-2.0.0
# ...
