# %%
print("test")
# Out:
# test

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="e1CD4XNuyqHtlQitfb78")
project = rf.workspace("joseph-nelson").project("bccd")
version = project.version(4)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to BCCD-4 in yolov5pytorch:: 100%|██████████| 1760/1760 [00:00<00:00, 6839.72it/s]

# %%
# !git clone https://github.com/wonbeomjang/yolov5-knowledge-distillation.git
# Out:
# Cloning into 'yolov5-knowledge-distillation'...
# remote: Enumerating objects: 15823, done.
# remote: Total 15823 (delta 0), reused 0 (delta 0), pack-reused 15823 (from 1)
# Receiving objects: 100% (15823/15823), 15.21 MiB | 14.38 MiB/s, done.
# Resolving deltas: 100% (10617/10617), done.

# %%
# %cd yolov5-knowledge-distillation/
# Out:
# /content/yolov5-knowledge-distillation

# %%
# !python train.py --data bccd4.yaml --cfg models/yolov5s_student.yaml --weights '' --batch-size 8 --teacher_weight yolov5s.pt --epochs 40
# Out:
# Streaming output truncated to the last 5000 lines.
#       14/39       1.5G    0.04213     0.1416   0.004552        143        640:  70% 67/96 [00:20<00:07,  3.63it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       14/39       1.5G    0.04216     0.1416   0.004552        159        640:  71% 68/96 [00:21<00:07,  3.88it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="e1CD4XNuyqHtlQitfb78")
project = rf.workspace("testppe").project("safety-safe-unsafe")
version = project.version(9)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Safety-Safe-Unsafe-9 in yolov5pytorch:: 100%|██████████| 3922/3922 [00:04<00:00, 938.10it/s]

# %%
# %cd yolov5-knowledge-distillation/
# Out:
# /content/yolov5-knowledge-distillation

# %%
# !python train.py --data safety_safe_unsafe.yaml --cfg models/yolov5s_student.yaml --weights '' --batch-size 8 --teacher_weight yolov5s.pt --epochs 40
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#       16/39      1.27G    0.05459    0.01851    0.01552         23        640:  63% 107/171 [00:39<00:18,  3.52it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       16/39      1.27G    0.05446    0.01847    0.01547         16        640:  63% 108/171 [00:39<00:19,  3.21it/s]/content/yolov5-knowledge-distillation/train.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
